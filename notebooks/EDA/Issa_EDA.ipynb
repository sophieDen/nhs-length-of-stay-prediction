# %% [markdown]
# Import statements

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# Data upload

# %%
df = pd.read_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/NHS_WWL_Dataset/wwlLancMsc_data.csv', low_memory=False)

# %% [markdown]
# Exploratory Data Analysis (EDA) - entire dataset

# %% [markdown]
# 1. Statistical Summary

# %%
df_desc = df.describe()
# Saves output to csv file
# df_desc.to_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/Descriptive_stats.csv')

print(df_desc)
# Out:
#        specialty_spec_code  duration_elective_wait  patient_age_on_admission  \
# count         41846.000000            17295.000000              41846.000000
# mean            244.584668              105.389303                 56.907470
# std             118.221109              172.722877                 23.284725
# min             100.000000                0.000000                  1.000000
# 25%             110.000000               18.000000                 41.000000
# 50%             300.000000               49.000000                 62.000000
# 75%             301.000000              132.000000                 75.000000
# max             560.000000             3415.000000                104.000000
#
#        patient_age_on_discharge  spell_episode_los  \
# count              41846.000000       41846.000000
# mean                  56.912274           1.759427
# std                   23.287412           5.281628
# min                    1.000000           0.000000
# ...

# %% [markdown]
# 2. Data Types (Summary)

# %%
d_types = df.dtypes

# d_types.to_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/Data Types.csv')


print(d_types)
# Out:
# site_national_code          object
# site_description            object
# site_local_code             object
# Admission_Date              object
# admission_date_dt           object
#                             ...
# attend_dis_description      object
# ae_unplanned_attendance    float64
# location                    object
# ID                           int64
# Deprivation Decile           int64
# Length: 101, dtype: object

# %% [markdown]
# Data Types (Counts)

# %%
df_dtype_counts = df.dtypes.value_counts()
# df_dtype_counts.to_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/DType Counts.csv')
print(df_dtype_counts)
# Out:
# int64      48
# object     45
# float64     8
# Name: count, dtype: int64

# %% [markdown]
# 3. Variance & Standard Deviation

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])
# Descriptive statistics for numeric outputs:
df_numeric_stats = pd.DataFrame({
    "Variance": numeric_df.var(),
    "Standard Deviation": numeric_df.std()
})
# df_numeric_stats.to_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/Outputs/Numeric_DescriptiveStats.csv')
print(df_numeric_stats)
# Out:
#                                                    Variance  \
# specialty_spec_code                            1.397623e+04
# duration_elective_wait                         2.983319e+04
# patient_age_on_admission                       5.421784e+02
# patient_age_on_discharge                       5.423036e+02
# spell_episode_los                              2.789559e+01
# discharge_delay_reason_national_code                    NaN
# delayed_discharges_flag                        4.779315e-05
# delayed_discharges_no_of_days                  4.898867e-03
# readmission_flag_28_days                       1.557506e-01
# readmission_flag_30_days                       1.591962e-01
# social_worker_date_time_referred                        NaN
# discharge_letter_sent_in_24hrs                 7.926669e-02
# inpatient_death_flag                           1.236560e-02
# spell_days_elective                            1.237809e+00
# spell_days_non_elective                        3.156609e+01
# ...

# %% [markdown]
# 4. Duplicate Rows

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# No duplicate rows detected in the dataset

# %% [markdown]
# ---

# %% [markdown]
# _Exploratory Data Analysis (Column 21 - 40)_

# %% [markdown]
# Segmented Data

# %%
df_21to40 = df.iloc[:,20:40]

# %% [markdown]
# 1. Descriptive Statistics

# %%
df_21to40.describe()
# Out:
#        discharge_delay_reason_national_code  delayed_discharges_flag  \
# count                                   0.0             41846.000000
# mean                                    NaN                 0.000048
# std                                     NaN                 0.006913
# min                                     NaN                 0.000000
# 25%                                     NaN                 0.000000
# 50%                                     NaN                 0.000000
# 75%                                     NaN                 0.000000
# max                                     NaN                 1.000000
#
#        delayed_discharges_no_of_days  readmission_flag_28_days  \
# count                   41846.000000              41846.000000
# mean                        0.000406                  0.192993
# std                         0.069992                  0.394653
# min                         0.000000                  0.000000
# ...

# %% [markdown]
# - Mode Calculation

# %%
df_21to40.mode(dropna=False)
# Out:
#    discharge_delay_reason_national_code discharge_delay_reason_description  \
# 0                                   NaN                       DW Generated
#
#   spell_dominant_proc spell_primary_diagnosis spell_secondary_diagnosis  \
# 0  Record not grouped      Record not grouped        Record not grouped
#
#   specialty_division specialty_directorate         hrg_group  \
# 0           Medicine              Medicine  Digestive System
#
#         hrg_sub_group  delayed_discharges_flag  delayed_discharges_no_of_days  \
# 0  Record not grouped                        0                              0
#
#    readmission_flag_28_days  readmission_flag_30_days  \
# 0                         0                         0
#
#    social_worker_date_time_referred discharge_letter_sent  \
# 0                               NaN                   NaN
#
#    discharge_letter_sent_in_24hrs  inpatient_death_flag  spell_days_elective  \
# ...

# %% [markdown]
# * Value Counts (Column 21 - 40)

# %%
for col in df_21to40.columns:
    print(f"{df_21to40.loc[:,col].value_counts()}\n")
# Out:
# Series([], Name: count, dtype: int64)
#
# discharge_delay_reason_description
# DW Generated           41844
# OTHER                      1
# EQUIPMENT - PATIENT        1
# Name: count, dtype: int64
#
# spell_dominant_proc
# Record not grouped    17781
# X292                   1712
# G451                   1490
# H229                    951
# H221                    737
#                       ...
# P189                      1
# T728+HAND                 1
# W087+FOOT                 1
# W778+FOOT                 1
# A088                      1
# Name: count, Length: 1461, dtype: int64
#
# spell_primary_diagnosis
# Record not grouped    1774
# M169                   918
# D509                   745
# M179                   670
# Z380                   658
#                       ...
# M0095                    1
# M4850                    1
# G08X                     1
# S0200                    1
# I609                     1
# Name: count, Length: 2602, dtype: int64
#
# ...

# %% [markdown]
# * Null Value Count

# %%
print(df_21to40.isnull().sum())
# Out:
# discharge_delay_reason_national_code    41846
# discharge_delay_reason_description          0
# spell_dominant_proc                         0
# spell_primary_diagnosis                     0
# spell_secondary_diagnosis                   0
# specialty_division                          0
# specialty_directorate                       0
# hrg_group                                   0
# hrg_sub_group                               0
# delayed_discharges_flag                     0
# delayed_discharges_no_of_days               0
# readmission_flag_28_days                    0
# readmission_flag_30_days                    0
# social_worker_date_time_referred        41846
# discharge_letter_sent                   17283
# discharge_letter_sent_in_24hrs          17283
# inpatient_death_flag                        0
# spell_days_elective                         0
# spell_days_non_elective                     0
# sex_national_code                           0
# dtype: int64

# %% [markdown]
# * Variance

# %%
numeric_df1 = df_21to40.select_dtypes(include=["int64", "float64"])
df_var = pd.DataFrame({
    "Variance": numeric_df1.var()})
print(df_var)
# Out:
#                                        Variance
# discharge_delay_reason_national_code        NaN
# delayed_discharges_flag                0.000048
# delayed_discharges_no_of_days          0.004899
# readmission_flag_28_days               0.155751
# readmission_flag_30_days               0.159196
# social_worker_date_time_referred            NaN
# discharge_letter_sent_in_24hrs         0.079267
# inpatient_death_flag                   0.012366
# spell_days_elective                    1.237809
# spell_days_non_elective               31.566092
# sex_national_code                      0.252430

# %% [markdown]
# Columns Deleted (below) -
#
# * **'inpatient_death_flag', 'spell_days_elective', 'delayed_discharges_no_of_days', 'spell_days_non_elective','delayed_discharges_no_of_days', 'delayed_discharges_flag', 'discharge_delay_reason_national_code', 'social_worker_date_time_referred', 'discharge_letter_sent','discharge_letter_sent_in_24hrs', 'delayed_discharges_no_of_days', 'discharge_delay_reason_description'.**
#
# This data would not be available to the model at the time of prediction, so would introduce data leakage if used in training

# %%
df_trimmed = df_21to40.drop(labels=['discharge_delay_reason_national_code', 'social_worker_date_time_referred', 'discharge_letter_sent', 'discharge_letter_sent_in_24hrs', 'inpatient_death_flag', 'spell_days_elective', 'spell_days_non_elective', 'delayed_discharges_no_of_days', "discharge_delay_reason_description", 'delayed_discharges_flag'], axis=1)
df_trimmed
# Out:
#       spell_dominant_proc spell_primary_diagnosis spell_secondary_diagnosis  \
# 0      Record not grouped                    K573                      I10X
# 1                    W901                    T845                      B957
# 2      Record not grouped                    K650                      K573
# 3                    B284                    C504                      I10X
# 4                    G451                    K227                      K317
# ...                   ...                     ...                       ...
# 41841  Record not grouped      Record not grouped        Record not grouped
# 41842  Record not grouped      Record not grouped        Record not grouped
# 41843  Record not grouped      Record not grouped        Record not grouped
# 41844  Record not grouped      Record not grouped        Record not grouped
# 41845  Record not grouped      Record not grouped        Record not grouped
#
#         specialty_division specialty_directorate  \
# ...

# %% [markdown]
# 2. Outlier Detection

# %% [markdown]
# All columns are categorical (binary flags, diagnostic codes, etc), so visualization methods such as boxplots or histograms don't apply.

# %% [markdown]
# * Unique Value Counts

# %%
col = df_trimmed.shape[1]
for i in range(col):
    output = df_trimmed.iloc[:,i].value_counts()
    print(f"Column {i+1}: \n{output}\n")
# Out:
# Column 1:
# spell_dominant_proc
# Record not grouped    17781
# X292                   1712
# G451                   1490
# H229                    951
# H221                    737
#                       ...
# P189                      1
# T728+HAND                 1
# W087+FOOT                 1
# W778+FOOT                 1
# A088                      1
# Name: count, Length: 1461, dtype: int64
#
# Column 2:
# spell_primary_diagnosis
# Record not grouped    1774
# M169                   918
# D509                   745
# M179                   670
# Z380                   658
#                       ...
# M0095                    1
# M4850                    1
# G08X                     1
# S0200                    1
# I609                     1
# Name: count, Length: 2602, dtype: int64
#
# Column 3:
# spell_secondary_diagnosis
# Record not grouped    4983
# I10X                  1706
# Z370                  1092
# J459                   727
# E119                   664
# ...

# %% [markdown]
# There are few rare categories seen in the different columns (e.g., categorical values that only appear once in the dataset), but this is expected when dealing with clinical data. All data seems to be valid (no data quality issues found)

# %% [markdown]
# No need to remove any "outliers" / rare categorical values, since tree-based models are already robust to outliers in nature.

# %% [markdown]
# ---

# %% [markdown]
# 3. Feature Engineering

# %% [markdown]
# * Encoding

# %% [markdown]
# _One-hot Encoding_

# %% [markdown]
# Columns encoded (below):
# * **"specialty_division"**
# * **"speciality_directorate"**

# %% [markdown]
# Preferred method - One-hot encoding (despite the increase in dimensionality, there is no risk of false ordinality, & it works well for linear & non-linear models.

# %%
df_trimmed = pd.get_dummies(df_trimmed, columns=["specialty_division"], prefix="spec_div")
df_trimmed = pd.get_dummies(df_trimmed, columns=["specialty_directorate"], prefix="spec_direc")

# %% [markdown]
# _Label Encoding_

# %% [markdown]
# Column encoded (below):
# * 'hrg_group'

# %%
df_trimmed["hrg_group"] = df_trimmed["hrg_group"].astype("category") # Changes data type from object to category, for label encoding
df_trimmed["hrg_group"] = df_trimmed["hrg_group"].cat.codes + 1 # Replaces column data with encoded category codes (adds 1 so categories start at 1 and not 0)
df_trimmed["hrg_group"].value_counts()
# Out:
# hrg_group
# 2     8117
# 12    6898
# 1     3433
# 15    2305
# 10    2222
# 3     2156
# 8     1945
# 4     1911
# 16    1891
# 18    1865
# 17    1798
# 13    1504
# 14    1447
# 5     1265
# 9      894
# 19     703
# 7      645
# 6      644
# 11     203
# Name: count, dtype: int64

# %% [markdown]
# Encoded Columns -
# * 'Cardiac Surgery and Primary Cardiac Conditions'
# * 'Digestive System'
# * 'Diseases of Childhood and Neonates'
# * 'Ear, Nose, Mouth, Throat, Neck and Dental'
# * 'Endocrine and Metabolic System'
# * 'Eyes and Periorbita'
# * 'Female Reproductive System and Assisted Reproduction'
# * 'Haematology, Chemotherapy, Radiotherapy and Specialist Palliative Care'
# * 'Hepatobiliary and Pancreatic System'
# * 'Immunology, Infectious Diseases and other contacts with Health Services'
# * 'Multiple Trauma, Emergency Medicine and Rehabilitation'
# * 'Musculoskeletal System'
# * 'Nervous System'
# * 'Obstetrics'
# * 'Respiratory System'
# * 'Skin, Breast and Burns'
# * 'Undefined Groups'
# * 'Urinary Tract and Male Reproductive System'
# * 'Vascular Procedures and Disorders and Imaging Interventions'

# %% [markdown]
# Sanity check - to verify that encoding was successful

# %%
df_trimmed["hrg_group"].value_counts()
# Out:
# hrg_group
# 2     8117
# 12    6898
# 1     3433
# 15    2305
# 10    2222
# 3     2156
# 8     1945
# 4     1911
# 16    1891
# 18    1865
# 17    1798
# 13    1504
# 14    1447
# 5     1265
# 9      894
# 19     703
# 7      645
# 6      644
# 11     203
# Name: count, dtype: int64

# %% [markdown]
# _CatBoost Encoding_

# %% [markdown]
# Target variable needed for this method, so have added our target variable column (**'spell_los_hrs'**) to the end of the dataset (for encoding purposes only) - see below

# %% [markdown]
# Columns encoded (below):
# * Spell_dominant_proc
# * spell_primary_diagnosis
# * spell_secondary_diagnosis
# * hrg_sub_group

# %% [markdown]
# Risk of CatBoost Encoding - target leakage (since the model will see the associated target variable of each category). So k-folds will be used to perform 'OUT OF FOLD' target encoding

# %%
from category_encoders import CatBoostEncoder
from sklearn.model_selection import KFold

# Append target column to the end of the split dataset (col 20-40):
df_trimmed["spell_los_hrs"] = df["spell_los_hrs"]

# Target variable
target = df_trimmed["spell_los_hrs"]
# Columns to be encoded:
col_to_encode = ["spell_dominant_proc",
                "spell_primary_diagnosis",
                "spell_secondary_diagnosis",
                "hrg_sub_group"]
# Define number of folds
k_folds = KFold(n_splits=4, shuffle=True, random_state=98)

# Create a copy to preserve original data (if needed in the future)
df_trimmed_encoded = df_trimmed.copy()

# Loops through column names to be encoded
for col in col_to_encode:

    # Placeholder - OOF values
    oof_values = pd.Series(index=df_trimmed.index, dtype=float)

    # OOF encoding per column:
    for tr_index, val_index in k_folds.split(df_trimmed):
        encoder = CatBoostEncoder(cols=[col],a=20.0)
        encoder.fit(df_trimmed.iloc[tr_index][[col]], target.iloc[tr_index])
        oof_values.iloc[val_index] = encoder.transform(df_trimmed.iloc[val_index][[col]])[col]

    df_trimmed_encoded[col + "_encoded"] = oof_values
    # Add frequency count - helps model performance
    freq = df_trimmed[col].map(df[col].value_counts())
    df_trimmed_encoded[col + "_count"] = freq

    # Adds 'rare flag' column (to indicate if the category is rare - useful to the model's performance)
    df_trimmed_encoded[col + "_is_rare"] = (freq < 10).astype(int)

# %%
df_trimmed_encoded.head(5)
# Out:
#   spell_dominant_proc spell_primary_diagnosis spell_secondary_diagnosis  \
# 0  Record not grouped                    K573                      I10X
# 1                W901                    T845                      B957
# 2  Record not grouped                    K650                      K573
# 3                B284                    C504                      I10X
# 4                G451                    K227                      K317
#
#    hrg_group                    hrg_sub_group  readmission_flag_28_days  \
# 0          2               Record not grouped                         0
# 1         19               Record not grouped                         0
# 2          2               Record not grouped                         1
# 3         16  Breast Procedures and Disorders                         0
# 4          2               Record not grouped                         0
#
#    readmission_flag_30_days  sex_national_code  spec_div_Medicine  \
# ...

# %% [markdown]
# Reorder columns

# %%
ordered_colnames = ['spell_dominant_proc', 'spell_dominant_proc_encoded', 'spell_dominant_proc_count',
       'spell_dominant_proc_is_rare','spell_primary_diagnosis','spell_primary_diagnosis_encoded',
       'spell_primary_diagnosis_count', 'spell_primary_diagnosis_is_rare',
       'spell_secondary_diagnosis', 'spell_secondary_diagnosis_encoded', 'spell_secondary_diagnosis_count',
       'spell_secondary_diagnosis_is_rare','spec_div_Medicine', 'spec_div_Specialist Services', 'spec_div_Surgery','spec_direc_Medicine','spec_direc_Specialist Services', 'spec_direc_Surgery', 'spec_direc_Womens Health', 'hrg_group', 'hrg_sub_group', 'hrg_sub_group_encoded',
       'hrg_sub_group_count', 'hrg_sub_group_is_rare', 'readmission_flag_28_days',
       'readmission_flag_30_days', 'sex_national_code', 'spell_los_hrs']

df_trimmed_encoded = df_trimmed_encoded[ordered_colnames]
# Copy
df_cleaned_21to40 = df_trimmed_encoded.copy()

# %% [markdown]
# -----

# %% [markdown]
# **Encoded & cleaned data so far**

# %%
df_cleaned_21to40.head(15)
# Out:
#    spell_dominant_proc  spell_dominant_proc_encoded  \
# 0   Record not grouped                    57.787969
# 1                 W901                    40.843008
# 2   Record not grouped                    57.905044
# 3                 B284                    33.007839
# 4                 G451                     9.378439
# 5                 G459                    30.718713
# 6   Record not grouped                    57.242409
# 7   Record not grouped                    57.962961
# 8                 G451                    14.831931
# 9   Record not grouped                    57.242409
# 10            X481+HIP                    49.800726
# 11                X381                    23.565533
# 12                G451                    15.157835
# 13                X384                     5.387262
# 14                G451                    13.594307
#
#     spell_dominant_proc_count  spell_dominant_proc_is_rare  \
# 0                       17781                            0
# ...

# %% [markdown]
# Dropping unencoded columns + target column (for cleanliness)

# %%
df_21to40_final = df_cleaned_21to40.drop(columns=["spell_dominant_proc", "spell_primary_diagnosis", "spell_secondary_diagnosis", "hrg_sub_group", "spell_los_hrs"])
df_21to40_final
# Out:
#        spell_dominant_proc_encoded  spell_dominant_proc_count  \
# 0                        57.787969                      17781
# 1                        40.843008                        222
# 2                        57.905044                      17781
# 3                        33.007839                         21
# 4                         9.378439                       1490
# ...                            ...                        ...
# 41841                    57.962961                      17781
# 41842                    57.905044                      17781
# 41843                    57.242409                      17781
# 41844                    57.962961                      17781
# 41845                    57.787969                      17781
#
#        spell_dominant_proc_is_rare  spell_primary_diagnosis_encoded  \
# 0                                0                        12.927096
# 1                                0                       134.068347
# ...

# %%
df_21to40_final.columns
# Out:
# Index(['spell_dominant_proc_encoded', 'spell_dominant_proc_count',
#        'spell_dominant_proc_is_rare', 'spell_primary_diagnosis_encoded',
#        'spell_primary_diagnosis_count', 'spell_primary_diagnosis_is_rare',
#        'spell_secondary_diagnosis_encoded', 'spell_secondary_diagnosis_count',
#        'spell_secondary_diagnosis_is_rare', 'spec_div_Medicine',
#        'spec_div_Specialist Services', 'spec_div_Surgery',
#        'spec_direc_Medicine', 'spec_direc_Specialist Services',
#        'spec_direc_Surgery', 'spec_direc_Womens Health', 'hrg_group',
#        'hrg_sub_group_encoded', 'hrg_sub_group_count', 'hrg_sub_group_is_rare',
#        'readmission_flag_28_days', 'readmission_flag_30_days',
#        'sex_national_code'],
#       dtype='object')

# %%
df_21to40_final
# Out:
#        spell_dominant_proc_encoded  spell_dominant_proc_count  \
# 0                        57.787969                      17781
# 1                        40.843008                        222
# 2                        57.905044                      17781
# 3                        33.007839                         21
# 4                         9.378439                       1490
# ...                            ...                        ...
# 41841                    57.962961                      17781
# 41842                    57.905044                      17781
# 41843                    57.242409                      17781
# 41844                    57.962961                      17781
# 41845                    57.787969                      17781
#
#        spell_dominant_proc_is_rare  spell_primary_diagnosis_encoded  \
# 0                                0                        12.927096
# 1                                0                       134.068347
# ...

# %% [markdown]
# Save cleaned data to csv (for combining later)

# %%
# df_21to40_final.to_csv('/Users/issandungu/Desktop/MSc Artificial Intelligence/Assignments/SCC450/Cleaned Dataset (21-40)/merge_Issa_col_21_40_cleaned.csv')

# %% [markdown]
# -----

# %% [markdown]
# * Feature Correlations (excluded "_frequency" and "_is_rare" columns, since those are only included to improve model performance)

# %%
df_21to40_final[['spell_dominant_proc_encoded', 'spell_primary_diagnosis_encoded',
       'spell_secondary_diagnosis_encoded', 'spec_div_Medicine',
       'spec_div_Specialist Services', 'spec_div_Surgery',
       'spec_direc_Medicine', 'spec_direc_Specialist Services',
       'spec_direc_Surgery', 'spec_direc_Womens Health', 'hrg_group',
       'hrg_sub_group_encoded', 'readmission_flag_28_days', 'readmission_flag_30_days',
       'sex_national_code']].corr().style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_7f5e5_row0_col0, #T_7f5e5_row1_col1, #T_7f5e5_row2_col2, #T_7f5e5_row3_col3, #T_7f5e5_row3_col6, #T_7f5e5_row4_col4, #T_7f5e5_row4_col7, #T_7f5e5_row5_col5, #T_7f5e5_row6_col3, #T_7f5e5_row6_col6, #T_7f5e5_row7_col4, #T_7f5e5_row7_col7, #T_7f5e5_row8_col8, #T_7f5e5_row9_col9, #T_7f5e5_row10_col10, #T_7f5e5_row11_col11, #T_7f5e5_row12_col12, #T_7f5e5_row13_col13, #T_7f5e5_row14_col14 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7f5e5_row0_col1, #T_7f5e5_row10_col4, #T_7f5e5_row10_col7 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_7f5e5_row0_col2 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_7f5e5_row0_col3, #T_7f5e5_row0_col6 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_7f5e5_row0_col4, #T_7f5e5_row0_col7 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_7f5e5_row0_col5, #T_7f5e5_row11_col10 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Readmission flag columns (28 days & 30 days) are highly correlated - makes sense to remove one of them (28 days suggested - since the '30 days' flag would still capture that same information)
